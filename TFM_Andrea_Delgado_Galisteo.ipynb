# %% [markdown]
# TFM - AEMET datos

# %%
API

# %%
import requests
import json
import pandas as pd

# %%
"""
Created on Thu Aug 18 19:19:32 2022

@author: andre
"""

url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/inventarioestaciones/todasestaciones/"

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhbmRyZWFkZ2FsaXNAZ21haWwuY29tIiwianRpIjoiZGFjZDgwNmYtNTk2Ny00MTkyLWE2YzYtM2I3M2VlYTQ5ZWY0IiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE2NjA4NDExMjIsInVzZXJJZCI6ImRhY2Q4MDZmLTU5NjctNDE5Mi1hNmM2LTNiNzNlZWE0OWVmNCIsInJvbGUiOiIifQ.faXcsh-CbHKYIkI0nO0vJp5eE4uEbq5B-n9v7LwMw3w"}

headers = {'cache-control': "no-cache"}

response = requests.request("GET", url, headers=headers, params=querystring)
url_data =  response.json()['datos']
json_df = requests.get(url_data).json()
inventario_estaciones = pd.json_normalize(json_df)

url2 = "https://opendata.aemet.es/opendata/api/maestro/municipios/"

response2 = requests.request("GET", url2, headers=headers, params=querystring).json()
municipios_aemet = pd.json_normalize(response2)

# %%
response2
# Out:
# [{'latitud': '40º32\'54.450744"',
#   'id_old': '44004',
#   'url': 'ababuj-id44001',
#   'latitud_dec': '40.54845854',
#   'altitud': '1372',
#   'capital': 'Ababuj',
#   'num_hab': '65',
#   'zona_comarcal': '624401',
#   'destacada': '0',
#   'nombre': 'Ababuj',
#   'longitud_dec': '-0.80780117',
#   'id': 'id44001',
#   'longitud': '-0º48\'28.084212"'},
#  {'latitud': '40º54\'58.824504"',
#   'id_old': '40004',
#   'url': 'abades-id40001',
#   'latitud_dec': '40.91634014',
#   'altitud': '971',
#   'capital': 'Abades',
#   'num_hab': '873',
#   'zona_comarcal': '674001',
#   'destacada': '0',
#   'nombre': 'Abades',
#   'longitud_dec': '-4.26787389',
#   'id': 'id40001',
#   'longitud': '-4º16\'4.346004"'},
#  {'latitud': '43º8\'51.525564"',
#   'id_old': '48010',
#   'url': 'abadino-abadino-zelaieta-id48001',
#   'latitud_dec': '43.14764599',
#   'altitud': '144',
#   'capital': 'Abadiño-Zelaieta',
#   'num_hab': '7504',
#   'zona_comarcal': '754802',
#   'destacada': '0',
# ...

# %%
df2.loc[df2["zona_comarcal"] == "670904"]
# Out:
#                latitud id_old                              url  latitud_dec  \
# 55    41º35'39.203988"  09006           adrada-de-haza-id09003  41.59422333
# 183   42º16'34.214628"  09018                 albillos-id09009  42.27617073
# 375     42º23'5.37162"  09023  alfoz-de-quintanaduenas-id09907  42.38482545
# 588    41º45'9.873936"  09032                   anguix-id09017  41.75274276
# 623   41º40'17.582844"  09034          aranda-de-duero-id09018  41.67155079
# ...                ...    ...                              ...          ...
# 7910  42º11'57.070212"  09858             villazopeque-id09472  42.19918617
# 7911   42º28'6.486456"  09860                 villegas-id09473  42.46846846
# 8024   42º6'35.209044"  09870                     zael-id09480  42.10978029
# 8065  42º32'10.358916"  09874  zarzosa-de-rio-pisuerga-id09482  42.53621081
# 8071  41º41'44.223828"  09876                   zazuar-id09483  41.69561773
#
# ...

# %% [markdown]
# Integramos con el fichero del INE de los municipios
